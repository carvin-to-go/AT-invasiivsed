# %% [markdown]
# # Importimised

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances
import numpy as np

# %%
#!pip install pandas openpyxl

# %%
pd.set_option('display.max_columns', None)  # or 1000
#pd.set_option('display.max_rows', None)  # or 1000

# %% [markdown]
# # sisselugemised

# %%
#excel file 1
EEB_samples = pd.ExcelFile('EEB_samples.xlsx') #file

sample = EEB_samples.parse('full_table') #sheet name
#samples_reynoutria = EEB_samples.parse('reynoutria') 
#samples_solidago = EEB_samples.parse('solidago') 

#excel file 2
EEB_soil_chemistry = pd.ExcelFile('EEB_soil_chemistry.xlsx')

soil = EEB_soil_chemistry.parse('Sheet1')

#excel file 3
plant_survey = pd.ExcelFile('Plant_survey_2023_final.xlsx') 

plant = plant_survey.parse('Sheet1')

# %% [markdown]
# ### eemaldame soil failist ühikute rea

# %%
soil=soil.iloc[1:] #eemaldasin ühikute rea
soil= soil.reset_index(drop=True)

# %% [markdown]
# # asjalik

# %%
#plant['liigirikkus'] = plant.apply(lambda row: (row != 0).sum(), axis=1)

# %%
#plt.plot(plant.liigirikkus,plant.Reynoutria_japonica,'mo')
#plt.plot(plant.liigirikkus,plant.Solidago_canadensis,'co')
#plt.title('Liigirikkus vs invasiivse liigi katvus')
#plt.show()

# %% [markdown]
# # keskmised

# %% [markdown]
#  - 123 inv
#  - 456trans
#  - 789nat

# %% [markdown]
# EEB-RJ1-1
#
# RJ taga indeks on 1 kuni 13
#
#
# EEB-SC1-1
#
# SC taga indeks 1 kuni 11
#
#
# viimane indeks 1-9 kõigil

# %%
#muudame nimesid
for i in range (1,14):
    for j in range(1,10):
        plant[plant['sample']=='EEB-RJ{}-{}'.format(i, j)]
        if j in range(1, 4):
            plant.loc[plant['sample'] == 'EEB-RJ{}-{}'.format(i, j), 'sample'] = 'INV-{}-R'.format(i)
        if j in range(4, 7): 
            plant.loc[plant['sample'] == 'EEB-RJ{}-{}'.format(i, j), 'sample'] = 'TRANS-{}-R'.format(i)
        if j in range(7, 10): 
            plant.loc[plant['sample'] == 'EEB-RJ{}-{}'.format(i, j), 'sample'] = 'NAT-{}-R'.format(i)
            
            
for i in range (1,12):
    for j in range(1,10):
        plant[plant['sample']=='EEB-SC{}-{}'.format(i, j)]
        if j in range(1, 4):
            plant.loc[plant['sample'] == 'EEB-SC{}-{}'.format(i, j), 'sample'] = 'INV-{}-S'.format(i)
        if j in range(4, 7): 
            plant.loc[plant['sample'] == 'EEB-SC{}-{}'.format(i, j), 'sample'] = 'TRANS-{}-S'.format(i)
        if j in range(7, 10): 
            plant.loc[plant['sample'] == 'EEB-SC{}-{}'.format(i, j), 'sample'] = 'NAT-{}-S'.format(i)

# %%
mean_df = plant.groupby('sample').mean()

# %%
kogu_katvus=mean_df.T.sum()
kogu_katvus
# Out:
# sample
# INV-1-R      105.166667
# INV-1-S       91.666667
# INV-10-R      77.000000
# INV-10-S      96.333333
# INV-11-R      99.333333
#                 ...
# TRANS-7-S     87.000000
# TRANS-8-R     73.333333
# TRANS-8-S     88.000000
# TRANS-9-R    119.333333
# TRANS-9-S     32.000000
# Length: 72, dtype: float64

# %%
invasiivsed=mean_df[['Reynoutria_japonica', 'Solidago_canadensis']]
invasiivsed
# Out:
#            Reynoutria_japonica  Solidago_canadensis
# sample
# INV-1-R              86.666667             0.000000
# INV-1-S               0.000000             0.000000
# INV-10-R             71.666667             0.000000
# INV-10-S              0.000000            87.333333
# INV-11-R             91.666667             0.000000
# ...                        ...                  ...
# TRANS-7-S             0.000000            25.000000
# TRANS-8-R            25.000000             0.000000
# TRANS-8-S             0.000000            30.000000
# TRANS-9-R            25.000000             0.000000
# TRANS-9-S             0.000000            11.333333
#
# [72 rows x 2 columns]

# %%
tavalised=mean_df.drop(['Reynoutria_japonica', 'Solidago_canadensis'],axis=1)
tavaliste_katvus=tavalised.T.sum()

# %%
invasiivsete_katvus=invasiivsed.T.sum()
invasiivsete_katvus
# Out:
# sample
# INV-1-R      86.666667
# INV-1-S       0.000000
# INV-10-R     71.666667
# INV-10-S     87.333333
# INV-11-R     91.666667
#                ...
# TRANS-7-S    25.000000
# TRANS-8-R    25.000000
# TRANS-8-S    30.000000
# TRANS-9-R    25.000000
# TRANS-9-S    11.333333
# Length: 72, dtype: float64

# %%
plt.plot(kogu_katvus,kogu_katvus/invasiivsete_katvus,'mo')
plt.title('Invasiivsete katvuse osakaal kogu katvusest')
plt.show()

# %%
plt.plot(invasiivsete_katvus,tavaliste_katvus,'mo')
plt.title('Invasiivsete vs tavaliste katvused')
plt.show()

# %%
#mean_df=mean_df.T
distances = pairwise_distances(mean_df.values)

# Convert the distances matrix to a DataFrame for better visualization
distances_df = pd.DataFrame(distances, index=mean_df.index, columns=mean_df.index)
distances_df
# Out:
# sample        INV-1-R     INV-1-S    INV-10-R    INV-10-S    INV-11-R  \
# sample
# INV-1-R      0.000000  102.598868   24.088379  124.521417   16.863010
# INV-1-S    102.598868    0.000000   90.695155  103.524823  106.945209
# INV-10-R    24.088379   90.695155    0.000000  112.992625   20.207259
# INV-10-S   124.521417  103.524823  112.992625    0.000000  126.660965
# INV-11-R    16.863010  106.945209   20.207259  126.660965    0.000000
# ...               ...         ...         ...         ...         ...
# TRANS-7-S   93.636561   61.742746   77.947276   64.831405   96.664943
# TRANS-8-R   63.276510   61.271255   49.843087   92.495646   68.494931
# TRANS-8-S   93.198265   66.091267   84.225227   65.970532  100.989548
# TRANS-9-R   90.939082   95.548998   97.183103  124.596683  106.104770
# TRANS-9-S   89.383848   56.254876   72.910143   76.401716   92.635486
#
# sample       INV-11-S    INV-12-R    INV-13-R     INV-2-R     INV-2-S  ...  \
# sample                                                                 ...
# INV-1-R    125.939249   81.503408   20.643132   36.628010  117.293909  ...
# INV-1-S    106.150574  138.237919   93.111343   79.918535   95.698891  ...
# INV-10-R   116.720940  101.602165    5.744563   18.697148  107.265248  ...
# INV-10-S    15.151091  160.698130  115.265394  104.761236  118.358448  ...
# INV-11-R   129.718070   97.136788   17.146428   36.762375  121.283186  ...
# ...               ...         ...         ...         ...         ...  ...
# TRANS-7-S   69.539757  138.152492   80.921773   65.090749   84.556030  ...
# TRANS-8-R   95.147254  109.331301   53.114133   37.890559   83.696210  ...
# TRANS-8-S   64.755094  118.845371   86.524242   72.493103   86.923657  ...
# TRANS-9-R  119.149299   67.539289   97.589845   91.410095  110.377383  ...
# TRANS-9-S   80.917654  134.896668   76.100810   59.019065   80.556743  ...
#
# sample      TRANS-5-R  TRANS-5-S  TRANS-6-R   TRANS-6-S  TRANS-7-R  TRANS-7-S  \
# sample
# INV-1-R     85.861646  95.569783  81.650509   98.988916  69.200393  93.636561
# INV-1-S     74.370506  61.037784  64.680840   70.824117  62.553533  61.742746
# INV-10-R    85.030550  80.259302  74.961472   84.301707  60.929832  77.947276
# INV-10-S   106.782619  65.345237  97.746270   91.896681  95.272708  64.831405
# INV-11-R    98.543702  98.536513  91.061640  101.852835  77.675250  96.664943
# ...               ...        ...        ...         ...        ...        ...
# TRANS-7-S   68.007965  23.414146  52.995807   48.491695  48.657533   0.000000
# TRANS-8-R   50.425688  47.580341  37.360109   54.113050  24.260164  43.582616
# TRANS-8-S   45.550643  39.568506  40.398020   58.983990  41.048752  36.269056
# TRANS-9-R   28.897808  95.678280  55.098901   99.077972  59.186147  93.746111
# TRANS-9-S   61.849055  27.778889  44.819391   44.151255  39.652659  21.758779
#
# sample     TRANS-8-R   TRANS-8-S   TRANS-9-R  TRANS-9-S
# sample
# INV-1-R    63.276510   93.198265   90.939082  89.383848
# INV-1-S    61.271255   66.091267   95.548998  56.254876
# INV-10-R   49.843087   84.225227   97.183103  72.910143
# INV-10-S   92.495646   65.970532  124.596683  76.401716
# INV-11-R   68.494931  100.989548  106.104770  92.635486
# ...              ...         ...         ...        ...
# TRANS-7-S  43.582616   36.269056   93.746111  21.758779
# TRANS-8-R   0.000000   45.995169   73.019023  33.349996
# TRANS-8-S  45.995169    0.000000   68.574372  37.196177
# TRANS-9-R  73.019023   68.574372    0.000000  89.028085
# TRANS-9-S  33.349996   37.196177   89.028085   0.000000
#
# [72 rows x 72 columns]

# %%
from sklearn import manifold
mds = manifold.MDS(n_components=2, dissimilarity='precomputed')
embedding = mds.fit_transform(distances_df)

plt.scatter(embedding[:, 0], embedding[:, 1])
plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.show()
# Out:
# C:\Anaconda\envs\IDS\lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
import numpy as np 
from sklearn import manifold
from sklearn.metrics import euclidean_distances
import matplotlib.pyplot as plt


native_coverage = plant.iloc[1:, 3:].values
invasive_coverage = plant.iloc[0:, :2].values
invasive_flipped = np.flip(invasive_coverage, 0)
dissimilarity = euclidean_distances(np.vstack(native_coverage))
dissimilarity
mds = manifold.MDS(n_components=2, dissimilarity='precomputed',normalized_stress="auto")
embedding = mds.fit_transform(dissimilarity)
values=samples_table.iloc[1:,12]
#values = np.random.rand(len(embedding))

plt.scatter(embedding[:, 0], embedding[:, 1], c=values, cmap='viridis')
plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.colorbar(label='values')  # to show color scale
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'distances_df' is your DataFrame with the pairwise distances
plt.figure(figsize=(10, 8))
sns.heatmap(distances_df, cmap='viridis')
plt.show()

# %%
distances1 = pairwise_distances(invasiivsed.values)

# Convert the distances matrix to a DataFrame for better visualization
distances_df1 = pd.DataFrame(distances1, index=invasiivsed.index, columns=invasiivsed.index)
distances_df1
# Out:
# sample        INV-1-R    INV-1-S    INV-10-R    INV-10-S    INV-11-R  \
# sample
# INV-1-R      0.000000  86.666667   15.000000  123.037483    5.000000
# INV-1-S     86.666667   0.000000   71.666667   87.333333   91.666667
# INV-10-R    15.000000  71.666667    0.000000  112.974432   20.000000
# INV-10-S   123.037483  87.333333  112.974432    0.000000  126.609197
# INV-11-R     5.000000  91.666667   20.000000  126.609197    0.000000
# ...               ...        ...         ...         ...         ...
# TRANS-7-S   90.200394  25.000000   75.901984   62.333333   95.014619
# TRANS-8-R   61.666667  25.000000   46.666667   90.841131   66.666667
# TRANS-8-S   91.712110  30.000000   77.692413   57.333333   96.450909
# TRANS-9-R   61.666667  25.000000   46.666667   90.841131   66.666667
# TRANS-9-S   87.404551  11.333333   72.557257   76.000000   92.364616
#
# sample       INV-11-S    INV-12-R    INV-13-R     INV-2-R    INV-2-S  ...  \
# sample                                                                ...
# INV-1-R    125.666667    4.000000   11.666667   30.000000  86.666667  ...
# INV-1-S     91.000000   90.666667   75.000000   56.666667   0.000000  ...
# INV-10-R   115.832254   19.000000    3.333333   15.000000  71.666667  ...
# INV-10-S     3.666667  125.887075  115.117814  104.106783  87.333333  ...
# INV-11-R   129.165699    1.000000   16.666667   35.000000  91.666667  ...
# ...               ...         ...         ...         ...        ...  ...
# TRANS-7-S   66.000000   94.050223   79.056942   61.936347  25.000000  ...
# TRANS-8-R   94.371606   65.666667   50.000000   31.666667  25.000000  ...
# TRANS-8-S   61.000000   95.501018   80.777472   64.117947  30.000000  ...
# TRANS-9-R   94.371606   65.666667   50.000000   31.666667  25.000000  ...
# TRANS-9-S   79.666667   91.372254   75.851463   57.788888  11.333333  ...
#
# sample     TRANS-5-R  TRANS-5-S  TRANS-6-R  TRANS-6-S  TRANS-7-R  TRANS-7-S  \
# sample
# INV-1-R    75.000000  90.676470  76.666667  86.922699  66.666667  90.200394
# INV-1-S    11.666667  26.666667  10.000000   6.666667  20.000000  25.000000
# INV-10-R   60.000000  76.467132  61.666667  71.976076  51.666667  75.901984
# INV-10-S   88.109149  60.666667  87.903988  80.666667  89.594147  62.333333
# INV-11-R   80.000000  95.466690  81.666667  91.908771  71.666667  95.014619
# ...              ...        ...        ...        ...        ...        ...
# TRANS-7-S  27.588242   1.666667  26.925824  18.333333  32.015621   0.000000
# TRANS-8-R  13.333333  36.552854  15.000000  25.873624   5.000000  35.355339
# TRANS-8-S  32.188680   3.333333  31.622777  23.333333  36.055513   5.000000
# TRANS-9-R  13.333333  36.552854  15.000000  25.873624   5.000000  35.355339
# TRANS-9-S  16.265164  15.333333  15.114379   4.666667  22.987920  13.666667
#
# sample     TRANS-8-R  TRANS-8-S  TRANS-9-R  TRANS-9-S
# sample
# INV-1-R    61.666667  91.712110  61.666667  87.404551
# INV-1-S    25.000000  30.000000  25.000000  11.333333
# INV-10-R   46.666667  77.692413  46.666667  72.557257
# INV-10-S   90.841131  57.333333  90.841131  76.000000
# INV-11-R   66.666667  96.450909  66.666667  92.364616
# ...              ...        ...        ...        ...
# TRANS-7-S  35.355339   5.000000  35.355339  13.666667
# TRANS-8-R   0.000000  39.051248   0.000000  27.448943
# TRANS-8-S  39.051248   0.000000  39.051248  18.666667
# TRANS-9-R   0.000000  39.051248   0.000000  27.448943
# TRANS-9-S  27.448943  18.666667  27.448943   0.000000
#
# [72 rows x 72 columns]

# %%
distances2 = pairwise_distances(tavalised.values)

# Convert the distances matrix to a DataFrame for better visualization
distances_df2 = pd.DataFrame(distances2, index=tavalised.index, columns=tavalised.index)
distances_df2
# Out:
# sample       INV-1-R    INV-1-S   INV-10-R   INV-10-S   INV-11-R   INV-11-S  \
# sample
# INV-1-R     0.000000  54.912810  18.848077  19.166667  16.104692   8.281505
# INV-1-S    54.912810   0.000000  55.583271  55.590267  55.086296  54.652945
# INV-10-R   18.848077  55.583271   0.000000   2.027588   2.886751  14.375906
# INV-10-S   19.166667  55.590267   2.027588   0.000000   3.620927  14.700718
# INV-11-R   16.104692  55.086296   2.886751   3.620927   0.000000  11.958261
# ...              ...        ...        ...        ...        ...        ...
# TRANS-7-S  25.133532  56.454997  17.738846  17.823206  17.785762  21.903830
# TRANS-8-R  14.182344  55.938955  17.508728  17.416467  15.719768  12.124356
# TRANS-8-S  16.577260  58.890199  32.523496  32.634338  29.935115  21.730675
# TRANS-9-R  66.836658  92.220448  85.245397  85.277325  82.545610  72.736205
# TRANS-9-S  18.706060  55.101422   7.164728   7.824463   7.078920  14.173528
#
# sample       INV-12-R   INV-13-R    INV-2-R     INV-2-S  ...  TRANS-5-R  \
# sample                                                   ...
# INV-1-R     81.405194  17.030202  21.014545   79.036384  ...  41.799787
# INV-1-S    104.351702  55.179002  56.354779   95.698891  ...  73.449718
# INV-10-R    99.809819   4.678556  11.161690   79.810540  ...  60.251095
# INV-10-S    99.881597   5.830952  11.691640   79.884987  ...  60.326657
# INV-11-R    97.131640   4.027682  11.245987   79.415574  ...  57.540083
# ...               ...        ...        ...         ...  ...        ...
# TRANS-7-S  101.196179  17.272329  20.017354   80.775753  ...  62.160858
# TRANS-8-R   87.414085  17.919573  20.806650   79.875250  ...  48.630980
# TRANS-8-S   70.737386  31.007168  33.825122   81.582610  ...  32.229645
# TRANS-9-R   15.793810  83.807982  85.749798  107.508914  ...  25.637971
# TRANS-9-S   99.238209   6.155395  11.987262   79.755529  ...  59.672020
#
# sample     TRANS-5-S  TRANS-6-R  TRANS-6-S  TRANS-7-R  TRANS-7-S  TRANS-8-R  \
# sample
# INV-1-R    30.188758  28.089638  47.362960  18.553975  25.133532  14.182344
# INV-1-S    54.904462  63.903139  70.509653  59.270097  56.454997  55.938955
# INV-10-R   24.378953  42.619766  43.888748  32.295511  17.738846  17.508728
# INV-10-S   24.280765  42.746020  44.021459  32.400274  17.823206  17.416467
# INV-11-R   24.404007  40.283716  43.895077  29.955523  17.785762  15.719768
# ...              ...        ...        ...        ...        ...        ...
# TRANS-7-S  23.354752  45.645981  44.892464  36.640900   0.000000  25.484200
# TRANS-8-R  30.459445  34.216630  47.526601  23.739325  25.484200   0.000000
# TRANS-8-S  39.427853  25.139610  54.172564  19.621417  35.922757  24.301349
# TRANS-9-R  88.420712  53.017817  95.639950  58.974571  86.823576  73.019023
# TRANS-9-S  23.163669  42.193996  43.903936  32.309269  16.931233  18.941430
#
# sample     TRANS-8-S  TRANS-9-R  TRANS-9-S
# sample
# INV-1-R    16.577260  66.836658  18.706060
# INV-1-S    58.890199  92.220448  55.101422
# INV-10-R   32.523496  85.245397   7.164728
# INV-10-S   32.634338  85.277325   7.824463
# INV-11-R   29.935115  82.545610   7.078920
# ...              ...        ...        ...
# TRANS-7-S  35.922757  86.823576  16.931233
# TRANS-8-R  24.301349  73.019023  18.941430
# TRANS-8-S   0.000000  56.368825  32.173143
# TRANS-9-R  56.368825   0.000000  84.690941
# TRANS-9-S  32.173143  84.690941   0.000000
#
# [72 rows x 72 columns]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(distances_df1, cmap='viridis')
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(distances_df2, cmap='viridis')
plt.show()

# %% [markdown]
# # liigirikkus

# %%
mean_df['liigirikkus'] = mean_df.apply(lambda row: (row != 0).sum(), axis=1)

# %%
plt.plot(mean_df.liigirikkus,invasiivsete_katvus,'mo')
plt.show()

# %%
mean_df.columns
# Out:
# Index(['Reynoutria_japonica', 'Solidago_canadensis', 'Aegopodium_podagraria',
#        'Ranunculus_auricomus', 'Alopecurus_pratensis', 'Elymus_repens',
#        'Agrostis_capillaris', 'Festuca_rubra', 'Cirsium_arvensis',
#        'Taraxacum_officinale',
#        ...
#        'Daucus_carota', 'Achillea_millefolia', 'Allium_scorodoprasum',
#        'Veronica_teucrium', 'Agrimonia_eupatoria', 'Plantago_media',
#        'Sonchus_arvensis', 'Prunus_domestica', 'Salix_alba', 'liigirikkus'],
#       dtype='object', length=222)

# %%
plt.plot(mean_df.liigirikkus,mean_df.Reynoutria_japonica,'mo')
plt.plot(mean_df.liigirikkus,mean_df.Solidago_canadensis,'co')
plt.plot(mean_df.liigirikkus,invasiivsete_katvus,'k.')
plt.title('Liigirikkus vs invasiivse liigi katvus')
plt.show()

# %% [markdown]
# # soil

# %%
soil.columns
# Out:
# Index(['ala_kood', 'Proovi nimetus', 'Nr.', 'Jrk. nr.', 'pHKCl', 'P-AL',
#        'K-AL', 'Ca-AL', 'Mg-AL', 'N -Kjeldahl', 'C-Tjurin'],
#       dtype='object')

# %%
soil_df=soil[['ala_kood','pHKCl']]
soil_df
# Out:
#     ala_kood  pHKCl
# 0    EEB-SC2   6.98
# 1    EEB-SC6   5.98
# 2    EEB-SC5   6.91
# 3    EEB-RJ4   6.68
# 4    EEB-RJ1   6.30
# 5    EEB-SC1   6.95
# 6    EEB-RJ3   6.39
# 7    EEB-SC8   5.62
# 8    EEB-RJ9   7.23
# 9    EEB-RJ8   6.46
# 10   EEB-RJ7   5.99
# 11   EEB-SC7   7.29
# 12   EEB-SC4   6.87
# 13  EEB-SC11   6.26
# 14  EEB-SC10   7.11
# 15  EEB-RJ13   6.78
# 16  EEB-RJ10   7.15
# 17  EEB-RJ11   7.16
# 18   EEB-RJ6   6.93
# 19   EEB-SC3   6.77
# 20   EEB-RJ5   6.11
# 21  EEB-RJ12   6.72
# 22   EEB-RJ2   7.16
# 23   EEB-SC9   7.03

# %%
soil_df[soil_df['ala_kood']=='EEB-RJ{}'.format(3)].pHKCl.values[0]
# Out:
# 6.39

# %%
for index, row in mean_df.iterrows():
    for i in range(1,14):
        if '{}-R'.format(i) in index:
            mean_df.loc[index, 'pH']=soil_df[soil_df['ala_kood']=='EEB-RJ{}'.format(i)].pHKCl.values[0]
        if '{}-S'.format(i) in index:
            mean_df.loc[index, 'pH']=soil_df[soil_df['ala_kood']=='EEB-SC{}'.format(i)].pHKCl.values[0]

# %%
mean_df
# Out:
#            Reynoutria_japonica  Solidago_canadensis  Aegopodium_podagraria  \
# sample
# INV-1-R              86.666667             0.000000              18.333333
# INV-1-S               0.000000             0.000000              10.666667
# INV-10-R             71.666667             0.000000               0.000000
# INV-10-S              0.000000            87.333333               0.000000
# INV-11-R             91.666667             0.000000               2.666667
# ...                        ...                  ...                    ...
# TRANS-7-S             0.000000            25.000000               0.000000
# TRANS-8-R            25.000000             0.000000              13.333333
# TRANS-8-S             0.000000            30.000000              30.000000
# TRANS-9-R            25.000000             0.000000              85.000000
# TRANS-9-S             0.000000            11.333333               0.666667
#
#            Ranunculus_auricomus  Alopecurus_pratensis  Elymus_repens  \
# sample
# INV-1-R                0.000000              0.000000       0.000000
# INV-1-S                0.000000              0.000000       0.166667
# INV-10-R               0.000000              0.000000       0.000000
# INV-10-S               0.000000              0.000000       0.666667
# INV-11-R               0.000000              0.000000       0.000000
# ...                         ...                   ...            ...
# TRANS-7-S              0.000000              0.000000       4.333333
# TRANS-8-R              0.000000              0.000000       0.000000
# TRANS-8-S              1.666667              0.333333       1.666667
# TRANS-9-R              0.000000              0.000000       0.333333
# TRANS-9-S              0.000000              0.666667       0.000000
#
#            Agrostis_capillaris  Festuca_rubra  Cirsium_arvensis  \
# sample
# INV-1-R               0.000000       0.000000               0.0
# INV-1-S               0.000000      16.666667               0.0
# INV-10-R              0.000000       0.000000               0.0
# INV-10-S              0.000000       0.333333               0.0
# INV-11-R              0.000000       0.000000               0.0
# ...                        ...            ...               ...
# TRANS-7-S             2.333333       5.000000               0.0
# TRANS-8-R             0.000000       0.000000               0.0
# TRANS-8-S             0.000000       0.000000               0.0
# TRANS-9-R             0.000000       0.000000               0.0
# TRANS-9-S             0.000000       1.666667               0.0
#
#            Taraxacum_officinale  ...  Achillea_millefolia  \
# sample                           ...
# INV-1-R                0.000000  ...                  0.0
# INV-1-S                0.000000  ...                  0.0
# INV-10-R               0.000000  ...                  0.0
# INV-10-S               0.000000  ...                  0.0
# INV-11-R               0.333333  ...                  0.0
# ...                         ...  ...                  ...
# TRANS-7-S              0.000000  ...                  0.0
# TRANS-8-R              0.000000  ...                  0.0
# TRANS-8-S              0.000000  ...                  0.0
# TRANS-9-R              0.000000  ...                  0.0
# TRANS-9-S              1.000000  ...                  0.0
#
#            Allium_scorodoprasum  Veronica_teucrium  Agrimonia_eupatoria  \
# sample
# INV-1-R                0.000000           0.000000             0.000000
# INV-1-S                0.000000           0.000000             0.000000
# INV-10-R               0.000000           0.000000             0.000000
# INV-10-S               0.000000           0.000000             0.000000
# INV-11-R               0.000000           0.000000             0.000000
# ...                         ...                ...                  ...
# TRANS-7-S              0.000000           0.000000             0.000000
# TRANS-8-R              0.000000           0.000000             0.000000
# TRANS-8-S              0.000000           0.000000             0.000000
# TRANS-9-R              0.000000           0.000000             0.000000
# TRANS-9-S              0.333333           0.666667             0.333333
#
#            Plantago_media  Sonchus_arvensis  Prunus_domestica  Salix_alba  \
# sample
# INV-1-R          0.000000               0.0          0.000000         0.0
# INV-1-S          0.000000               0.0          0.000000         0.0
# INV-10-R         0.000000               0.0          0.000000         0.0
# INV-10-S         0.000000               0.0          0.000000         0.0
# INV-11-R         0.000000               0.0          0.333333         0.0
# ...                   ...               ...               ...         ...
# TRANS-7-S        0.000000               0.0          0.000000         0.0
# TRANS-8-R        0.000000               0.0          0.000000         0.0
# TRANS-8-S        0.000000               0.0          0.000000         0.0
# TRANS-9-R        0.000000               0.0          0.000000         0.0
# TRANS-9-S        0.333333               0.0          0.000000         0.0
#
#            liigirikkus    pH
# sample
# INV-1-R              3  6.30
# INV-1-S             30  6.95
# INV-10-R             5  7.15
# INV-10-S             9  7.11
# INV-11-R             7  7.16
# ...                ...   ...
# TRANS-7-S           25  7.29
# TRANS-8-R           14  6.46
# TRANS-8-S           19  5.62
# TRANS-9-R            8  7.23
# TRANS-9-S           27  7.03
#
# [72 rows x 223 columns]

# %%
# for index, row in mean_df.iterrows():
#     if 'INV-' in index:
#         mean_df.loc[index, 'invadeeritus']='INV'
#     if 'TRANS-' in index:
#         mean_df.loc[index, 'invadeeritus']='TRANS'
#     if 'NAT-' in index:
#         mean_df.loc[index, 'invadeeritus']='NAT'
# Out:
# C:\Users\reeli\AppData\Local\Temp\ipykernel_39220\1556100342.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'INV' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mean_df.loc[index, 'invadeeritus']='INV'

# %%
for index, row in mean_df.iterrows():
    if 'INV-' in index:
        mean_df.loc[index, 'invadeeritus']=1
    if 'TRANS-' in index:
        mean_df.loc[index, 'invadeeritus']=2
    if 'NAT-' in index:
        mean_df.loc[index, 'invadeeritus']=3

# %%
mean_df
# Out:
#            Reynoutria_japonica  Solidago_canadensis  Aegopodium_podagraria  \
# sample
# INV-1-R              86.666667             0.000000              18.333333
# INV-1-S               0.000000             0.000000              10.666667
# INV-10-R             71.666667             0.000000               0.000000
# INV-10-S              0.000000            87.333333               0.000000
# INV-11-R             91.666667             0.000000               2.666667
# ...                        ...                  ...                    ...
# TRANS-7-S             0.000000            25.000000               0.000000
# TRANS-8-R            25.000000             0.000000              13.333333
# TRANS-8-S             0.000000            30.000000              30.000000
# TRANS-9-R            25.000000             0.000000              85.000000
# TRANS-9-S             0.000000            11.333333               0.666667
#
#            Ranunculus_auricomus  Alopecurus_pratensis  Elymus_repens  \
# sample
# INV-1-R                0.000000              0.000000       0.000000
# INV-1-S                0.000000              0.000000       0.166667
# INV-10-R               0.000000              0.000000       0.000000
# INV-10-S               0.000000              0.000000       0.666667
# INV-11-R               0.000000              0.000000       0.000000
# ...                         ...                   ...            ...
# TRANS-7-S              0.000000              0.000000       4.333333
# TRANS-8-R              0.000000              0.000000       0.000000
# TRANS-8-S              1.666667              0.333333       1.666667
# TRANS-9-R              0.000000              0.000000       0.333333
# TRANS-9-S              0.000000              0.666667       0.000000
#
#            Agrostis_capillaris  Festuca_rubra  Cirsium_arvensis  \
# sample
# INV-1-R               0.000000       0.000000               0.0
# INV-1-S               0.000000      16.666667               0.0
# INV-10-R              0.000000       0.000000               0.0
# INV-10-S              0.000000       0.333333               0.0
# INV-11-R              0.000000       0.000000               0.0
# ...                        ...            ...               ...
# TRANS-7-S             2.333333       5.000000               0.0
# TRANS-8-R             0.000000       0.000000               0.0
# TRANS-8-S             0.000000       0.000000               0.0
# TRANS-9-R             0.000000       0.000000               0.0
# TRANS-9-S             0.000000       1.666667               0.0
#
#            Taraxacum_officinale  ...  Allium_scorodoprasum  Veronica_teucrium  \
# sample                           ...
# INV-1-R                0.000000  ...              0.000000           0.000000
# INV-1-S                0.000000  ...              0.000000           0.000000
# INV-10-R               0.000000  ...              0.000000           0.000000
# INV-10-S               0.000000  ...              0.000000           0.000000
# INV-11-R               0.333333  ...              0.000000           0.000000
# ...                         ...  ...                   ...                ...
# TRANS-7-S              0.000000  ...              0.000000           0.000000
# TRANS-8-R              0.000000  ...              0.000000           0.000000
# TRANS-8-S              0.000000  ...              0.000000           0.000000
# TRANS-9-R              0.000000  ...              0.000000           0.000000
# TRANS-9-S              1.000000  ...              0.333333           0.666667
#
#            Agrimonia_eupatoria  Plantago_media  Sonchus_arvensis  \
# sample
# INV-1-R               0.000000        0.000000               0.0
# INV-1-S               0.000000        0.000000               0.0
# INV-10-R              0.000000        0.000000               0.0
# INV-10-S              0.000000        0.000000               0.0
# INV-11-R              0.000000        0.000000               0.0
# ...                        ...             ...               ...
# TRANS-7-S             0.000000        0.000000               0.0
# TRANS-8-R             0.000000        0.000000               0.0
# TRANS-8-S             0.000000        0.000000               0.0
# TRANS-9-R             0.000000        0.000000               0.0
# TRANS-9-S             0.333333        0.333333               0.0
#
#            Prunus_domestica  Salix_alba  liigirikkus    pH  invadeeritus
# sample
# INV-1-R            0.000000         0.0            3  6.30             1
# INV-1-S            0.000000         0.0           30  6.95             1
# INV-10-R           0.000000         0.0            5  7.15             1
# INV-10-S           0.000000         0.0            9  7.11             1
# INV-11-R           0.333333         0.0            7  7.16             1
# ...                     ...         ...          ...   ...           ...
# TRANS-7-S          0.000000         0.0           25  7.29             2
# TRANS-8-R          0.000000         0.0           14  6.46             2
# TRANS-8-S          0.000000         0.0           19  5.62             2
# TRANS-9-R          0.000000         0.0            8  7.23             2
# TRANS-9-S          0.000000         0.0           27  7.03             2
#
# [72 rows x 224 columns]

# %%
from sklearn import manifold
mds = manifold.MDS(n_components=2, dissimilarity='precomputed',normalized_stress="auto") #normalized_stress=False
embedding = mds.fit_transform(distances_df)
invadeeritus=mean_df.invadeeritus.values

plt.scatter(embedding[:, 0], embedding[:, 1],c=invadeeritus, cmap='viridis')
plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.colorbar(label='values')

plt.show()

# %% [markdown]
# - 1= INV
# - 2=TRANS
# - 3=NAT

# %%
from sklearn import manifold
mds = manifold.MDS(n_components=2, dissimilarity='precomputed',normalized_stress="auto")
embedding = mds.fit_transform(distances_df)
pH=mean_df.pH.values

plt.scatter(embedding[:, 0], embedding[:, 1],c=pH, cmap='viridis')
plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.colorbar(label='values')
plt.show()
#stress valued vaadata???
# värvid panna invaded, mitte invaded, transitional

# %%
distances_df
# Out:
# sample        INV-1-R     INV-1-S    INV-10-R    INV-10-S    INV-11-R  \
# sample
# INV-1-R      0.000000  102.598868   24.088379  124.521417   16.863010
# INV-1-S    102.598868    0.000000   90.695155  103.524823  106.945209
# INV-10-R    24.088379   90.695155    0.000000  112.992625   20.207259
# INV-10-S   124.521417  103.524823  112.992625    0.000000  126.660965
# INV-11-R    16.863010  106.945209   20.207259  126.660965    0.000000
# ...               ...         ...         ...         ...         ...
# TRANS-7-S   93.636561   61.742746   77.947276   64.831405   96.664943
# TRANS-8-R   63.276510   61.271255   49.843087   92.495646   68.494931
# TRANS-8-S   93.198265   66.091267   84.225227   65.970532  100.989548
# TRANS-9-R   90.939082   95.548998   97.183103  124.596683  106.104770
# TRANS-9-S   89.383848   56.254876   72.910143   76.401716   92.635486
#
# sample       INV-11-S    INV-12-R    INV-13-R     INV-2-R     INV-2-S  ...  \
# sample                                                                 ...
# INV-1-R    125.939249   81.503408   20.643132   36.628010  117.293909  ...
# INV-1-S    106.150574  138.237919   93.111343   79.918535   95.698891  ...
# INV-10-R   116.720940  101.602165    5.744563   18.697148  107.265248  ...
# INV-10-S    15.151091  160.698130  115.265394  104.761236  118.358448  ...
# INV-11-R   129.718070   97.136788   17.146428   36.762375  121.283186  ...
# ...               ...         ...         ...         ...         ...  ...
# TRANS-7-S   69.539757  138.152492   80.921773   65.090749   84.556030  ...
# TRANS-8-R   95.147254  109.331301   53.114133   37.890559   83.696210  ...
# TRANS-8-S   64.755094  118.845371   86.524242   72.493103   86.923657  ...
# TRANS-9-R  119.149299   67.539289   97.589845   91.410095  110.377383  ...
# TRANS-9-S   80.917654  134.896668   76.100810   59.019065   80.556743  ...
#
# sample      TRANS-5-R  TRANS-5-S  TRANS-6-R   TRANS-6-S  TRANS-7-R  TRANS-7-S  \
# sample
# INV-1-R     85.861646  95.569783  81.650509   98.988916  69.200393  93.636561
# INV-1-S     74.370506  61.037784  64.680840   70.824117  62.553533  61.742746
# INV-10-R    85.030550  80.259302  74.961472   84.301707  60.929832  77.947276
# INV-10-S   106.782619  65.345237  97.746270   91.896681  95.272708  64.831405
# INV-11-R    98.543702  98.536513  91.061640  101.852835  77.675250  96.664943
# ...               ...        ...        ...         ...        ...        ...
# TRANS-7-S   68.007965  23.414146  52.995807   48.491695  48.657533   0.000000
# TRANS-8-R   50.425688  47.580341  37.360109   54.113050  24.260164  43.582616
# TRANS-8-S   45.550643  39.568506  40.398020   58.983990  41.048752  36.269056
# TRANS-9-R   28.897808  95.678280  55.098901   99.077972  59.186147  93.746111
# TRANS-9-S   61.849055  27.778889  44.819391   44.151255  39.652659  21.758779
#
# sample     TRANS-8-R   TRANS-8-S   TRANS-9-R  TRANS-9-S
# sample
# INV-1-R    63.276510   93.198265   90.939082  89.383848
# INV-1-S    61.271255   66.091267   95.548998  56.254876
# INV-10-R   49.843087   84.225227   97.183103  72.910143
# INV-10-S   92.495646   65.970532  124.596683  76.401716
# INV-11-R   68.494931  100.989548  106.104770  92.635486
# ...              ...         ...         ...        ...
# TRANS-7-S  43.582616   36.269056   93.746111  21.758779
# TRANS-8-R   0.000000   45.995169   73.019023  33.349996
# TRANS-8-S  45.995169    0.000000   68.574372  37.196177
# TRANS-9-R  73.019023   68.574372    0.000000  89.028085
# TRANS-9-S  33.349996   37.196177   89.028085   0.000000
#
# [72 rows x 72 columns]

# %%
embedding
# Out:
# array([[ 73.71159503,  16.08426474],
#        [-54.61502832, -10.47656877],
#        [ 64.76935372,  -2.96657296],
#        [-21.16000367, -83.57527012],
#        [ 82.68950695,   3.58380206],
#        [-32.83363358, -80.8181645 ],
#        [ 59.98520195,  91.42739196],
#        [ 67.56016605,  -0.91474998],
#        [ 51.55833457,  -6.21617441],
#        [-83.99043224,  -2.18571046],
#        [ 28.91372763,  -9.8937287 ],
#        [ -9.26942525, -61.02806937],
#        [ 67.34347282,   4.71959159],
#        [-18.67811086, -80.30273039],
#        [ 62.13757945,   0.14710042],
#        [-21.04326425, -63.9807951 ],
#        [ 26.89810507,  74.52033926],
#        [-14.4902259 , -56.12978397],
#        [ 29.48845751,  45.48406519],
#        [ -4.10472846, -59.97440552],
#        [ 42.47052557,  19.73151772],
#        [-29.2615527 , -67.41571792],
#        [ 65.05793671,   1.34369008],
#        [-17.31733846, -77.00192429],
#        [-16.70334852,  49.1305099 ],
#        [-22.7973237 , -11.07022949],
#        [-52.62604353,  10.25517072],
#        [  6.78544487, -10.99623048],
#        [-26.07499457,  42.90969234],
#        [ -2.04443877,  -6.06548061],
#        [-24.18422581,  75.71169767],
#        [-23.46213604,  72.57755531],
#        [ -7.5397468 , -17.89933297],
#        [-22.89190504,  58.74414772],
#        [ 64.09320395, -70.54199854],
#        [  3.36589463, -15.97640114],
#        [-23.70581127,  13.04754537],
#        [ -0.61099285, -16.91140574],
#        [-18.90167373,  10.74998536],
#        [ 10.57888895, -23.86477228],
#        [-16.59106811,  40.90682613],
#        [-49.03525053, -24.1968398 ],
#        [ -7.4857863 ,   9.2137759 ],
#        [  6.87365584, -19.11895371],
#        [-13.79940275,  15.96301779],
#        [ -4.3072358 ,  -1.75666698],
#        [-21.18416836,  66.52383984],
#        [ -5.187178  , -11.12197339],
#        [ -3.31287433,  55.38041699],
#        [-27.44065037, -17.99444182],
#        [-46.51895951,  -1.88439145],
#        [  2.11286736, -28.3276594 ],
#        [-11.21598368,  39.76460469],
#        [-12.42125395, -27.77007751],
#        [-18.64510005,  75.9591734 ],
#        [-16.77005598,  76.22850906],
#        [ 20.29949608, -21.9215356 ],
#        [-37.47624046,  61.74184229],
#        [ 33.12690938, -23.01171331],
#        [  1.80479067, -18.54444713],
#        [ 12.16642818,   9.8339961 ],
#        [ -2.30510523, -22.68353492],
#        [ -3.61525806,  38.8182912 ],
#        [ -7.51964224, -36.41342188],
#        [  0.66254525,  19.93488182],
#        [-36.84006712, -27.67627259],
#        [ 10.24316418,  13.07402907],
#        [ -2.12807575, -34.52118954],
#        [ 18.88577712,  -0.22685621],
#        [-21.88427942,  -3.16644259],
#        [  2.20976836,  64.52452544],
#        [ -1.80277749, -21.49316156]])

# %%
from sklearn import manifold
mds = manifold.MDS(n_components=2, dissimilarity='precomputed')
embedding = mds.fit_transform(distances_df)
pH=mean_df.pH.values

plt.scatter(embedding[:, 0], embedding[:, 1],c=pH, cmap='viridis')
plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.colorbar(label='values')
plt.show()
# Out:
# C:\Anaconda\envs\IDS\lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
#!pip install folium
# Out:
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/18/09/8569904c8ce5679cc02826d98de633c07abcd2443a23181e5f71ff9dacbc/folium-0.15.1-py2.py3-none-any.whl.metadata
#   Downloading folium-0.15.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/2f/e7/603b136221de923055716d23e3047da71f92e0d8ba2c4517ce49a54fe768/branca-0.7.0-py3-none-any.whl.metadata
#   Downloading branca-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\anaconda\envs\ids\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\anaconda\envs\ids\lib\site-packages (from folium) (1.26.0)
# Requirement already satisfied: requests in c:\anaconda\envs\ids\lib\site-packages (from folium) (2.31.0)
# Collecting xyzservices (from folium)
#   Obtaining dependency information for xyzservices from https://files.pythonhosted.org/packages/82/c3/e06dfa46464cce3eda4b86df8847cab99d9bc545c76807ee689545187a4c/xyzservices-2023.10.1-py3-none-any.whl.metadata
#   Downloading xyzservices-2023.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\envs\ids\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\envs\ids\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\ids\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\ids\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\ids\lib\site-packages (from requests->folium) (2023.7.22)
# Downloading folium-0.15.1-py2.py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/97.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/97.0 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/97.0 kB 325.1 kB/s eta 0:00:01
#    ------------ --------------------------- 30.7/97.0 kB 325.1 kB/s eta 0:00:01
#    ------------------------------------- -- 92.2/97.0 kB 476.3 kB/s eta 0:00:01
#    ---------------------------------------- 97.0/97.0 kB 427.6 kB/s eta 0:00:00
# Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Downloading xyzservices-2023.10.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.3 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/56.3 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 56.3/56.3 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.0 folium-0.15.1 xyzservices-2023.10.1

# %%
sample
# Out:
#        new_code project plant_sp sampling_area(on_bag) treatment  \
# 0     EEB-RJ1-1     EEB       RJ               Mustvee   control
# 1     EEB-RJ1-2     EEB       RJ               Mustvee   control
# 2     EEB-RJ1-3     EEB       RJ               Mustvee   control
# 3     EEB-RJ1-4     EEB       RJ               Mustvee   control
# 4     EEB-RJ1-5     EEB       RJ               Mustvee   control
# ..          ...     ...      ...                   ...       ...
# 211  EEB-SC11-5     EEB       SC                Kaimri      mown
# 212  EEB-SC11-6     EEB       SC                Kaimri      mown
# 213  EEB-SC11-7     EEB       SC                Kaimri      mown
# 214  EEB-SC11-8     EEB       SC                Kaimri      mown
# 215  EEB-SC11-9     EEB       SC                Kaimri      mown
#
#      sampling_area_nr      gradient  grad_nr  plant_nr  expert area  \
# 0                   1       invaded        1         1   Kadri    E
# 1                   1       invaded        2         2   Kadri    E
# 2                   1       invaded        3         3   Kadri    E
# 3                   1  transitional        1         4   Kadri    E
# 4                   1  transitional        2         5   Kadri    E
# ..                ...           ...      ...       ...     ...  ...
# 211                11  transitional        2         5  Oliver    W
# 212                11  transitional        3         6  Oliver    W
# 213                11       natural        1         7  Oliver    W
# 214                11       natural        2         8  Oliver    W
# 215                11       natural        3         9  Oliver    W
#
#            lat        lon status _dna_extraction
# 0    58.858114  26.931854                    NaN
# 1    58.858114  26.931854                    NaN
# 2    58.858114  26.931854                    NaN
# 3    58.858114  26.931854                    NaN
# 4    58.858114  26.931854                    NaN
# ..         ...        ...                    ...
# 211  58.060173  22.207555                    NaN
# 212  58.060173  22.207555                    NaN
# 213  58.060173  22.207555                    NaN
# 214  58.060173  22.207555                    NaN
# 215  58.060173  22.207555                    NaN
#
# [216 rows x 14 columns]

# %%
import folium

# Create a map centered at an initial location
initial_latitude=58.595272
initial_longitude=25.013607
map = folium.Map(location=[initial_latitude, initial_longitude], zoom_start=7)

# Add points to the map
for index, row in sample.iterrows():
    folium.Marker([row['lat'], row['lon']]).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_316cdd8419ee39b760661893db9522bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_316cdd8419ee39b760661893db9522bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_316cdd8419ee39b760661893db9522bd = L.map(
#                 &quot;map_316cdd8419ee39b760661893db9522bd&quot;,
#                 {
#                     center: [58.595272, 25.013607],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_736e30a8a38c012419c5d2e56ccf4e2a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_736e30a8a38c012419c5d2e56ccf4e2a.addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_bedd1429701ae1550e52a34481cd0520 = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_799fe70fcbbde152d88fc7f607ec5d4c = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_9ddd9c772447c425d0b3911f5aada338 = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_ea98a3e90978430697de283e8a209573 = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_e131d4eeef3cefb7ab398e34ac74b3bc = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_2fdba29e9f60110313cbbcef1fd257ee = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_c9f61d0c570700c0c76bab73dccc151f = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_963092a9399206127c0b26f2cdedc8c0 = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_5b9094099f36b748e4dda649a41b53fc = L.marker(
#                 [58.85811356, 26.93185398],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_dc94f9ca4ff8d28fe9dd3c1eb034d5bd = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_a61dd454cc4e3f902c129cd3a34269d3 = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_c5330c6c34c2486138dbfd57a4131de8 = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_d64e7ab3de1b966885e1cb0e0ac6596e = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_ee2640a612b383c675ea7a68e95d6841 = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_60e49ef09e53c2a500b4b7f7191a7fe4 = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_1debee2df868c4126bddea0866b03463 = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_a462d4fb4c7de8069384a38c6f636d7f = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_f245871810ba17475d82435aa1bc2c8d = L.marker(
#                 [58.39350723, 26.71039833],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_931e4d708615dac28ed94d5f6dc8c128 = L.marker(
#                 [58.73816673, 27.07395442],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_d5aa75e505ed53d25f452fb4e8b27b51 = L.marker(
#                 [58.73816673, 27.07395442],
#                 {}
#             ).addTo(map_316cdd8419ee39b760661893db9522bd);
#
#
#             var marker_cf42cd4077481701ee18be812f3967d1 = L.marker(
